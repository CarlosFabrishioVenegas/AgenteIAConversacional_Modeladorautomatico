# %% [markdown]
# # EDA — Propensión de Compra
# Análisis exploratorio del dataset de 58,693 visitas de clientes.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.ingestion import load_config, load_raw_data
from src.visualization.eda import (
    plot_distributions, plot_target_distribution, plot_correlation_matrix
)

cfg = load_config('../config/config.yaml')
df  = load_raw_data(config=cfg)
df.head()

# %%
# Estadísticas descriptivas
df.describe().T.style.background_gradient(cmap='Blues').format('{:.2f}')

# %%
# Distribución del target
plot_target_distribution(df, target='incidencia_compra', output_dir='../outputs/reports/images')

# %%
# Distribuciones numéricas
continuous = ['edad', 'ingreso_anual', 'precio_marca_1', 'precio_marca_2', 'precio_marca_3']
plot_distributions(df, columnas=continuous, hue_col='incidencia_compra',
                   output_dir='../outputs/reports/images', filename='distribuciones_eda.png')

# %%
# Correlación
plot_correlation_matrix(df, output_dir='../outputs/reports/images')
